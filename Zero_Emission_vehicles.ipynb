# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
import plotly.express as px
from pathlib import Path
from dataclasses import dataclass
import requests

# %% [markdown]
# # Point 4: Accelerating the Shift to Zero Emission Vehicles,
# End the sale of new pure
# petrol and diesel cars and
# vans by 2030 and consult on
# phase out for diesel HGVs

# %% [markdown]
# ## What % of cars on the road today are Zero Emission?

# %%
make_model_df = pd.read_csv(Path("raw_data","vehicles", "by_make_model.csv"))
make_model_df = make_model_df[make_model_df['LicenceStatus'] == 'Licensed']

quarters_cols = ['2022Q3',
       '2022Q2', '2022Q1', '2021Q4', '2021Q3', '2021Q2', '2021Q1', '2020Q4',
       '2020Q3', '2020Q2', '2020Q1', '2019Q4', '2019Q3', '2019Q2', '2019Q1',
       '2018Q4', '2018Q3', '2018Q2', '2018Q1', '2017Q4', '2017Q3', '2017Q2',
       '2017Q1', '2016Q4', '2016Q3', '2016Q2', '2016Q1', '2015Q4', '2015Q3',
       '2015Q2', '2015Q1', '2014Q4', '2014Q3', '2014Q2', '2014Q1', '2013Q4',
       '2013Q3', '2013Q2', '2013Q1', '2012Q4', '2012Q3', '2012Q2', '2012Q1',
       '2011Q4', '2011Q3', '2011Q2', '2011Q1', '2010Q4', '2010Q3', '2010Q2',
       '2010Q1', '2009Q4', '2009Q3', '2009Q2', '2009Q1', '2008Q4', '2008Q3',
       '2007Q4', '2006Q4', '2005Q4', '2004Q4', '2003Q4', '2002Q4', '2001Q4',
       '2000Q4', '1999Q4', '1998Q4', '1997Q4', '1996Q4', '1995Q4', '1994Q4']

# make_model_df['total'] = make_model_df.sum(numeric_only = True, axis = 1)

make_model_df = make_model_df[quarters_cols].T
make_model_df['total'] = make_model_df.sum(numeric_only = True, axis = 1)
make_model_df = make_model_df.iloc[::-1] #Reversing index for chronological order
make_model_df
fig = px.line(make_model_df, x=make_model_df.index, y="total", title='Total vehicles licensed in the UK', template='plotly_dark', 
              labels={
                     "index": "Date",
                     "total": "Num. Vehicles",
                 },)
fig.show()

# %%
make_model_df = make_model_df.reset_index()
make_model_df.head()
make_model_df = make_model_df[['index', 'total']]
make_model_df['date_stripped' ] = make_model_df['index'].str.slice(0,4) + " " + make_model_df['index'].str.slice(4, 6)
make_model_df= make_model_df.rename(columns = {'total':'total licensed vehicles'})
make_model_df = make_model_df.drop('index', axis = 1)

# %%
piv_df_raw = pd.read_excel(Path("raw_data", "vehicles", "veh0141_PIV.ods"), engine="odf", sheet_name='VEH0141a_Fuel', skiprows = 4)
piv_df = piv_df_raw.copy()

# %%
piv_df = piv_df[piv_df['Geography [note 2]'] == 'United Kingdom']
piv_df = piv_df[piv_df['Units'] == 'Number']
piv_df = piv_df.drop(['Geography [note 2]', 'Units', 'Battery Electric','Plug-in hybrid electric (petrol)',	'Plug-in hybrid electric (diesel)',	'Range extended electric'], axis = 1)

# %%
def strip_date(string:str):
    years = []
    for i, _ in enumerate(range(150)):
        year = 1900 + i
        years.append(str(year)) 
    quarters = ["Q1", "Q2", "Q3", "Q4"]
    to_keep = years + quarters
    return ' '.join([x for x in string.split() if x in to_keep])

# %%
piv_df['date_stripped'] = piv_df['Date'].apply(lambda x: strip_date(x))
piv_df['Total'] = piv_df['Total'].astype(float)
piv_df_grouped = piv_df.groupby('date_stripped').sum(numeric_only = True)

# %%
fig = px.line(piv_df_grouped, x=piv_df_grouped.index, y="Total", title='Plug in vehicles licensed in the UK', template='plotly_dark', 
                            labels={
                     "date_stripped": "Date",
                     "Total": "Num. Vehicles",
                 }) # This is all vehicles - HGV, Buses, motorbikes, cars
fig.show()

# %%
piv_df_grouped = piv_df_grouped.rename(columns = {'Total':'total plug in vehicles licensed'}).reset_index()

# %%
merged_df = make_model_df.merge(piv_df_grouped, how = 'left')

# %%
fig = px.line(merged_df, x='date_stripped',
              y=["total plug in vehicles licensed","total licensed vehicles"], 
              title='Plug in vehicles licensed in the UK', 
              template='plotly_dark', 
               labels={
                     "date_stripped": "Date",
                     "value": "Num. Vehicles",
                 }) # This is all vehicles - HGV, Buses, motorbikes, cars
fig.update_layout(legend_title_text=' ')
fig.update_layout(legend=dict(
    yanchor="top",
    y=1.4,
    xanchor="left",
    x=0.4
))
fig.show()

# %% [markdown]
# Back to the original question - what % of cars today are zero emission? Note the only data available is for plug in cars, not necessarily zero emission (includes hybrids)

# %%
merged_df['% Plug in vehicles'] = 100*(merged_df['total plug in vehicles licensed'] / merged_df['total licensed vehicles'])

# %%
merged_df.tail()
# Out:
#     total licensed vehicles date_stripped  total plug in vehicles licensed  \
# 66                 39236290       2021 Q3                        1302632.0
# 67                 39034266       2021 Q4                        1495790.0
# 68                 39123642       2022 Q1                        1686476.0
# 69                 39430211       2022 Q2                        1843810.0
# 70                 39519623       2022 Q3                        2006144.0
#
#     % Plug in vehicles
# 66            3.319967
# 67            3.831992
# 68            4.310631
# 69            4.676135
# 70            5.076324

# %% [markdown]
# ## What % of cars over the last 5 years sold have been zero emission?

# %% [markdown]
# ## Whats the average cost of a zero emission car compared to petrol/diesel?

# %% [markdown]
# The cost of a new zero emisison car is a big hurdle for a lot of buyers, as these are typically much more expnsive than a low cost petrol or diesel car. Although savings can be made up through lower cost of fuel, the government may need to implement a help to buy system if they want people buying more electric.

# %%
# https://www.edfenergy.com/energywise/cheapest-electric-cars-to-buy
#https://www.autoexpress.co.uk/best-cars-vans/351901/top-10-cheapest-cars-sale-2023
@dataclass
class Car:
    name: str
    price: int

@dataclass
class ElectricCar(Car):
    range: int
    
vw_id3 = ElectricCar("VW ID.3 Life Pro Performance", 29990, 265)
peugeot_e_208 = ElectricCar("Peugeot e-208", 30195, 217)
vauxhall_corsa_e = ElectricCar("Vauxhall Corsa-e", 29995, 209)
nissan_leaf_acenta = ElectricCar("Nissan Leaf Acenta", 28995, 168)
mg_zs_ev = ElectricCar("MG ZS EV", 18995, 165)
mg4_ev = ElectricCar("MG4 EV", 25995, 218)
ds3_crossback_etense = ElectricCar("DS3 Crossback E-Tense", 33935, 191)
vw_e_up = ElectricCar("VW e-Up", 23555, 140)
mini_electric = ElectricCar("MINI Electric", 28000, 140)
fiat_500e = ElectricCar("Fiat 500e", 23495, 115)

dacia_sandero = Car('Dacia Sandero',12595)
mg3 = Car('MG3',13295)
kia_picanto = Car('Kia Picanto',13400)
hyundai_i10 = Car('Hyundai i10',13430)
dacia_sandero_stepway = Car('Dacia Sandero Stepway',13795)
citroen_c3 = Car('Citroen C3',13995)
volkswagen_up = Car('Volkswagen up!',14070)
fiat_panda = Car('Fiat Panda',14485)
fiat_500_hybrid = Car('Fiat 500 hybrid',14990)
dacia_duster = Car('Dacia Duster',15295)
fiat_panda = Car('Fiat Panda',14485)
fiat_500_hybrid = Car('Fiat 500 hybrid',14990)
dacia_duster = Car('Dacia Duster',15295)

# %% [markdown]
# Lets compare the price of the cheapest electric cars on sale in the UK today with the cheapest petrol/diesel cars available

# %%
electric_car_list = [vw_id3,
peugeot_e_208,
vauxhall_corsa_e,
nissan_leaf_acenta,
mg_zs_ev,
mg4_ev,
ds3_crossback_etense,
vw_e_up,
mini_electric,
fiat_500e]

car_list = [dacia_sandero,
mg3,
kia_picanto,
hyundai_i10,
dacia_sandero_stepway,
citroen_c3,
volkswagen_up,
fiat_panda,
fiat_500_hybrid,
dacia_duster,
fiat_panda,
fiat_500_hybrid,
dacia_duster,
]

# %%
electric_df = pd.DataFrame(electric_car_list).sort_values(by = 'price')
electric_df['type'] = 'Electric'
petrol_diesel_df = pd.DataFrame(car_list).sort_values(by = 'price')
petrol_diesel_df['type'] = 'Petrol/Diesel'

car_df = pd.concat([electric_df, petrol_diesel_df]).drop_duplicates()

# %%
fig = px.bar(car_df, x='name', y='price', 
             title='Electric and Petrol/Diesel Car Prices', 
             color = 'type',
              template='plotly_dark', 
              labels={
                     "name": "Name",
                     "price": "Price (£)",
                 })
fig.update_layout(legend_title_text=' ')
fig.update_layout(legend=dict(
    yanchor="top",
    y=1.45,
    xanchor="left",
    x=0.25
))
fig.show()

# %% [markdown]
# The cheapest electric car is £4000 more expensive than the most expensive petrol/diesel car.
#
# Let's see how price can impact range on these budget electric cars.

# %%
car_df.head()
# Out:
#             name  price  range      type
# 4       MG ZS EV  18995  165.0  Electric
# 9      Fiat 500e  23495  115.0  Electric
# 7        VW e-Up  23555  140.0  Electric
# 5         MG4 EV  25995  218.0  Electric
# 8  MINI Electric  28000  140.0  Electric

# %%
fig = px.scatter(car_df[car_df['type'] == 'Electric'], x='range', y='price', 
             title='Budget Electric car Price vs Range', 
              template='plotly_dark', 
              hover_data = ['name', 'price', 'range'],
              labels={
                     "range": "Range (Miles)",
                     "price": "Price (£)",
                 })

fig.show()

# %% [markdown]
# # How many chargers are available, and where are they located?

# %% [markdown]
# Charging data is available via the NCR API
#
#
# https://chargepoints.dft.gov.uk/api/help

# %%
api_url = r"http://chargepoints.dft.gov.uk/api/retrieve/registry/format/csv"
charger_df = pd.read_csv(api_url, lineterminator='\n')
# Out:
# C:\Users\MoroJ\AppData\Local\Temp\ipykernel_18288\3007469401.py:2: DtypeWarning:
#
# Columns (5,10,11,17,18,49,54,56,57,58,59,60,61,62,63,64,65,90,101,112,115,119,122,123,126,130,133,134,137,141,144,148,152,155) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
charger_df.head()
# Out:
#                      chargeDeviceID reference  \
# 0  9c8661befae6dbcd08304dbf4dcaf0db      SC22
# 1  52b738b303d90a884137546353e09ebb      SC23
# 2  b58ac8403eb9cf17fae1dcd16df71fde      SC33
# 3  fd8c07a31f8a85910ad8476f5f7efb27      SC03
# 4  f507783927f2ec2737ba40afbd17efb5      SC19
#
#                                        name   latitude  longitude  \
# 0    Little Victoria St Car Park - Socket 2  54.592703  -5.933430
# 1  Little Donegall Street, Belfast (Socket   54.604646  -5.931866
# 2         Cromac Street Car Park (Socket 2)  54.594109  -5.924292
# 3  Hope Street Car Park, Belfast (Socket 2)  54.593365  -5.935574
# 4       Adelaide Street, Belfast (Socket 2)  54.594342  -5.928256
#
#   subBuildingName                buildingName buildingNumber  \
# 0             NaN  DRD Roads Service Car Park              4
# 1             NaN                         NaN            128
# 2             NaN                         NaN          89-97
# 3             NaN                         NaN            205
# 4             NaN                         NaN          23-91
#
#              thoroughfare        street doubleDependantLocality  \
# 0         Downshire Place           NaN                     NaN
# 1  Little Donegall Street           NaN                     NaN
# 2           Cromac Street           NaN                     NaN
# 3               Sandy Row  Bruce Street                     NaN
# 4         Adelaide Street           NaN                     NaN
#
#   dependantLocality     town         county  postcode countryCode  uprn  \
# 0           Belfast  Belfast  County Antrim   BT2 7JQ          gb   NaN
# 1               NaN  Belfast  County Antrim   BT1 2JD          gb   NaN
# 2               NaN  Belfast  County Antrim   BT2 8JN          gb   NaN
# 3               NaN  Belfast  County Antrim  BT12 5ED          gb   NaN
# 4               NaN  Belfast  County Antrim   BT2 8GB          gb   NaN
#
#                                    deviceDescription  \
# 0                         DRD Roads Service Car Park
# 1  On-street charging point on Little Donegall St...
# 2  DRD Car Park on Cromac Street, usual car parki...
# 3      DRD car park, Hope Street North, Bruce Street
# 4           Adelaide Street on-street charging post
#
#                             locationShortDescription  \
# 0                Little Victoria Street DRD Car Park
# 1  On-street charging point on Little Donegall St...
# 2                      DRD Car Park on Cromac Street
# 3      DRD car park, Hope Street North, Bruce Street
# 4                          Adelaide Street on-street
#
#                              locationLongDescription deviceManufacturer  \
# 0                                                NaN                NaN
# 1  On-street charging point on Little Donegall St...                NaN
# 2  DRD Car Park on Cromac Street, usual car parki...                NaN
# 3  DRD car park, Hope Street North, Bruce Street ...                NaN
# 4  Adelaide Street on-street charging post outsid...                NaN
#
#   deviceModel deviceOwnerName        deviceOwnerWebsite  \
# 0         NaN       ecars ESB  https://www.esb.ie/ecars
# 1         NaN       ecars ESB  https://www.esb.ie/ecars
# 2         NaN       ecars ESB  https://www.esb.ie/ecars
# 3         NaN       ecars ESB  https://www.esb.ie/ecars
# 4         NaN       ecars ESB  https://www.esb.ie/ecars
#
#   deviceOwnerTelephoneNo  deviceOwnerContactName deviceControllerName  \
# 0        00353 1258 3799                     NaN            ecars ESB
# 1        00353 1258 3799                     NaN            ecars ESB
# 2        00353 1258 3799                     NaN            ecars ESB
# 3        00353 1258 3799                     NaN            ecars ESB
# 4        00353 1258 3799                     NaN            ecars ESB
#
#     deviceControllerWebsite deviceControllerTelephoneNo  \
# 0  https://www.esb.ie/ecars             00353 1258 3799
# 1  https://www.esb.ie/ecars             00353 1258 3799
# 2  https://www.esb.ie/ecars             00353 1258 3799
# 3  https://www.esb.ie/ecars             00353 1258 3799
# 4  https://www.esb.ie/ecars             00353 1258 3799
#
#    deviceControllerContactName deviceNetworks chargeDeviceStatus  \
# 0                          NaN      ecars ESB         In service
# 1                          NaN      ecars ESB         In service
# 2                          NaN      ecars ESB     Out of service
# 3                          NaN      ecars ESB         In service
# 4                          NaN      ecars ESB         In service
#
#   publishStatus  deviceValidated          dateCreated          dateUpdated  \
# 0     Published                0  2012-04-12 10:17:49  2023-02-16 15:30:32
# 1     Published                0  2012-04-12 14:00:01  2021-07-07 09:40:22
# 2     Published                0  2012-04-12 14:10:27  2021-07-07 09:40:36
# 3     Published                0  2012-04-12 14:16:09  2021-07-07 09:40:52
# 4     Published                0  2012-04-12 14:17:57  2021-07-07 09:41:04
#
#   moderated          lastUpdated lastUpdatedBy attribution  dateDeleted  \
# 0         Y  2021-07-06 11:16:43   EB Charging   ecars ESB          NaN
# 1         Y  2021-07-06 11:24:08   EB Charging   ecars ESB          NaN
# 2         Y  2021-07-06 11:24:26   EB Charging   ecars ESB          NaN
# 3         Y  2021-07-06 11:24:44   EB Charging   ecars ESB          NaN
# 4         Y  2021-07-06 11:25:17   EB Charging   ecars ESB          NaN
#
#    paymentRequired paymentRequiredDetails  subscriptionRequired  \
# 0                0                    NaN                     1
# 1                1                    NaN                     1
# 2                1                    NaN                     1
# 3                1                    NaN                     1
# 4                1                    NaN                     1
#
#   subscriptionRequiredDetails  parkingFeesFlag parkingFeesDetails  \
# 0                         NaN                0                NaN
# 1                         NaN                0                NaN
# 2                         NaN                0                NaN
# 3                         NaN                0                NaN
# 4                         NaN                0                NaN
#
#   parkingFeesUrl  accessRestrictionFlag accessRestrictionDetails  \
# 0            NaN                      0                      NaN
# 1            NaN                      0                      NaN
# 2            NaN                      0                      NaN
# 3            NaN                      0                      NaN
# 4            NaN                      0                      NaN
#
#    physicalRestrictionFlag physicalRestrictionText  onStreetFlag  \
# 0                      0.0                     NaN           0.0
# 1                      0.0                     NaN           1.0
# 2                      0.0                     NaN           0.0
# 3                      0.0                     NaN           0.0
# 4                      0.0                     NaN           1.0
#
#       locationType bearing  access24Hours accessMondayFrom accessMondayTo  \
# 0  Public car park     NaN            0.0              NaN            NaN
# 1        On-street     NaN            0.0              NaN            NaN
# 2  Public car park     NaN            0.0              NaN            NaN
# 3  Public car park     NaN            0.0              NaN            NaN
# 4        On-street     NaN            0.0              NaN            NaN
#
#   accessTuesdayFrom accessTuesdayTo accessWednesdayFrom accessWednesdayTo  \
# 0               NaN             NaN                 NaN               NaN
# 1               NaN             NaN                 NaN               NaN
# 2               NaN             NaN                 NaN               NaN
# 3               NaN             NaN                 NaN               NaN
# 4               NaN             NaN                 NaN               NaN
#
#   accessThursdayFrom accessThursdayTo accessFridayFrom accessFridayTo  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#   accessSaturdayFrom accessSaturdayTo accessSundayFrom accessSundayTo  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    connector1ID              connector1Type  connector1RatedOutputKW  \
# 0          5757  Type 2 Mennekes (IEC62196)                     22.0
# 1          5761  Type 2 Mennekes (IEC62196)                     22.0
# 2          5763  Type 2 Mennekes (IEC62196)                     22.0
# 3          5765  Type 2 Mennekes (IEC62196)                     22.0
# 4          5767  Type 2 Mennekes (IEC62196)                     22.0
#
#    connector1OutputCurrent  connector1RatedVoltage connector1ChargeMethod  \
# 0                       32                     400         Three Phase AC
# 1                       32                     400         Three Phase AC
# 2                       32                     400         Three Phase AC
# 3                       32                     400         Three Phase AC
# 4                       32                     400         Three Phase AC
#
#    connector1ChargeMode  connector1TetheredCable connector1Status  \
# 0                     3                        0       In service
# 1                     3                        0       In service
# 2                     3                        0   Out of service
# 3                     3                        0       In service
# 4                     3                        0       In service
#
#   connector1Description  connector1Validated  connector2ID  \
# 0                   NaN                    0        5758.0
# 1                   NaN                    0        5762.0
# 2                   NaN                    0        5764.0
# 3                   NaN                    0        5766.0
# 4                   NaN                    0        5768.0
#
#                connector2Type  connector2RatedOutputKW  \
# 0  Type 2 Mennekes (IEC62196)                     22.0
# 1  Type 2 Mennekes (IEC62196)                     22.0
# 2  Type 2 Mennekes (IEC62196)                     22.0
# 3  Type 2 Mennekes (IEC62196)                     22.0
# 4  Type 2 Mennekes (IEC62196)                     22.0
#
#    connector2OutputCurrent  connector2RatedVoltage connector2ChargeMethod  \
# 0                     32.0                   400.0         Three Phase AC
# 1                     32.0                   400.0         Three Phase AC
# 2                     32.0                   400.0         Three Phase AC
# 3                     32.0                   400.0         Three Phase AC
# 4                     32.0                   400.0         Three Phase AC
#
#    connector2ChargeMode  connector2TetheredCable connector2Status  \
# 0                   3.0                      0.0       In service
# 1                   3.0                      0.0       In service
# 2                   3.0                      0.0   Out of service
# 3                   3.0                      0.0       In service
# 4                   3.0                      0.0       In service
#
#   connector2Description  connector2Validated  connector3ID connector3Type  \
# 0                   NaN                  0.0           NaN            NaN
# 1                   NaN                  0.0           NaN            NaN
# 2                   NaN                  0.0           NaN            NaN
# 3                   NaN                  0.0           NaN            NaN
# 4                   NaN                  0.0           NaN            NaN
#
#    connector3RatedOutputKW  connector3OutputCurrent  connector3RatedVoltage  \
# 0                      NaN                      NaN                     NaN
# 1                      NaN                      NaN                     NaN
# 2                      NaN                      NaN                     NaN
# 3                      NaN                      NaN                     NaN
# 4                      NaN                      NaN                     NaN
#
#   connector3ChargeMethod  connector3ChargeMode  connector3TetheredCable  \
# 0                    NaN                   NaN                      NaN
# 1                    NaN                   NaN                      NaN
# 2                    NaN                   NaN                      NaN
# 3                    NaN                   NaN                      NaN
# 4                    NaN                   NaN                      NaN
#
#   connector3Status connector3Description  connector3Validated  connector4ID  \
# 0              NaN                   NaN                  NaN           NaN
# 1              NaN                   NaN                  NaN           NaN
# 2              NaN                   NaN                  NaN           NaN
# 3              NaN                   NaN                  NaN           NaN
# 4              NaN                   NaN                  NaN           NaN
#
#   connector4Type  connector4RatedOutputKW  connector4OutputCurrent  \
# 0            NaN                      NaN                      NaN
# 1            NaN                      NaN                      NaN
# 2            NaN                      NaN                      NaN
# 3            NaN                      NaN                      NaN
# 4            NaN                      NaN                      NaN
#
#    connector4RatedVoltage connector4ChargeMethod  connector4ChargeMode  \
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
#
#    connector4TetheredCable connector4Status connector4Description  \
# 0                      NaN              NaN                   NaN
# 1                      NaN              NaN                   NaN
# 2                      NaN              NaN                   NaN
# 3                      NaN              NaN                   NaN
# 4                      NaN              NaN                   NaN
#
#    connector4Validated  connector5ID connector5Type  connector5RatedOutputKW  \
# 0                  NaN           NaN            NaN                      NaN
# 1                  NaN           NaN            NaN                      NaN
# 2                  NaN           NaN            NaN                      NaN
# 3                  NaN           NaN            NaN                      NaN
# 4                  NaN           NaN            NaN                      NaN
#
#    connector5OutputCurrent  connector5RatedVoltage connector5ChargeMethod  \
# 0                      NaN                     NaN                    NaN
# 1                      NaN                     NaN                    NaN
# 2                      NaN                     NaN                    NaN
# 3                      NaN                     NaN                    NaN
# 4                      NaN                     NaN                    NaN
#
#    connector5ChargeMode  connector5TetheredCable connector5Status  \
# 0                   NaN                      NaN              NaN
# 1                   NaN                      NaN              NaN
# 2                   NaN                      NaN              NaN
# 3                   NaN                      NaN              NaN
# 4                   NaN                      NaN              NaN
#
#   connector5Description  connector5Validated  connector6ID connector6Type  \
# 0                   NaN                  NaN           NaN            NaN
# 1                   NaN                  NaN           NaN            NaN
# 2                   NaN                  NaN           NaN            NaN
# 3                   NaN                  NaN           NaN            NaN
# 4                   NaN                  NaN           NaN            NaN
#
#    connector6RatedOutputKW  connector6OutputCurrent  connector6RatedVoltage  \
# 0                      NaN                      NaN                     NaN
# 1                      NaN                      NaN                     NaN
# 2                      NaN                      NaN                     NaN
# 3                      NaN                      NaN                     NaN
# 4                      NaN                      NaN                     NaN
#
#   connector6ChargeMethod  connector6ChargeMode  connector6TetheredCable  \
# 0                    NaN                   NaN                      NaN
# 1                    NaN                   NaN                      NaN
# 2                    NaN                   NaN                      NaN
# 3                    NaN                   NaN                      NaN
# 4                    NaN                   NaN                      NaN
#
#   connector6Status connector6Description  connector6Validated  connector7ID  \
# 0              NaN                   NaN                  NaN           NaN
# 1              NaN                   NaN                  NaN           NaN
# 2              NaN                   NaN                  NaN           NaN
# 3              NaN                   NaN                  NaN           NaN
# 4              NaN                   NaN                  NaN           NaN
#
#   connector7Type  connector7RatedOutputKW  connector7OutputCurrent  \
# 0            NaN                      NaN                      NaN
# 1            NaN                      NaN                      NaN
# 2            NaN                      NaN                      NaN
# 3            NaN                      NaN                      NaN
# 4            NaN                      NaN                      NaN
#
#    connector7RatedVoltage connector7ChargeMethod  connector7ChargeMode  \
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
#
#    connector7TetheredCable connector7Status  connector7Description  \
# 0                      NaN              NaN                    NaN
# 1                      NaN              NaN                    NaN
# 2                      NaN              NaN                    NaN
# 3                      NaN              NaN                    NaN
# 4                      NaN              NaN                    NaN
#
#    connector7Validated  connector8ID connector8Type  connector8RatedOutputKW  \
# 0                  NaN           NaN            NaN                      NaN
# 1                  NaN           NaN            NaN                      NaN
# 2                  NaN           NaN            NaN                      NaN
# 3                  NaN           NaN            NaN                      NaN
# 4                  NaN           NaN            NaN                      NaN
#
#    connector8OutputCurrent  connector8RatedVoltage connector8ChargeMethod  \
# 0                      NaN                     NaN                    NaN
# 1                      NaN                     NaN                    NaN
# 2                      NaN                     NaN                    NaN
# 3                      NaN                     NaN                    NaN
# 4                      NaN                     NaN                    NaN
#
#    connector8ChargeMode  connector8TetheredCable connector8Status  \
# 0                   NaN                      NaN              NaN
# 1                   NaN                      NaN              NaN
# 2                   NaN                      NaN              NaN
# 3                   NaN                      NaN              NaN
# 4                   NaN                      NaN              NaN
#
#    connector8Description  connector8Validated
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN

# %%
with open('mapbox_token.txt') as f:
    token = f.read()

# %%
px.set_mapbox_access_token(token)
fig = px.scatter_mapbox(charger_df, lat="latitude", lon="longitude", color = 'connector1RatedOutputKW', size_max=15, zoom=3.5, hover_data=['name'])
fig.show()

# %%
bins = [50,150,]
